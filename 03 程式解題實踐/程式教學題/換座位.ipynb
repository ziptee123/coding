# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/%E7%A8%8B%E5%BC%8F%E6%95%99%E5%AD%B8%E9%A1%8C/%E6%8F%9B%E5%BA%A7%E4%BD%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#換座位
#改編自2020 資訊學科能力競賽 新北區複賽
m,n=map(int,input().split())
mat=[i for i in range(1,m+1)] #i預設從0,但學號是1
for _ in range(n):
  a,b=map(int,input().split())
  mat[a-1],mat[b-1]=mat[b-1],mat[a-1] #直接交換(記得加1)
print(*mat)
#原本沒想到mat[a-1],mat[b-1]=mat[b-1],mat[a-1]這樣直接交換
#當時想多設一個同樣的list，一個放改變後的
#matr=[j for j in range(1,m+1)]
#for _ in range(n):
  #a,b=map(int,input().split())
  #mat[a-1]=matr[b-1]
  #mat[b-1]=matr[a-1]
