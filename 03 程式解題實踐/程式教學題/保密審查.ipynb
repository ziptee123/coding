# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/%E7%A8%8B%E5%BC%8F%E6%95%99%E5%AD%B8%E9%A1%8C/%E4%BF%9D%E5%AF%86%E5%AF%A9%E6%9F%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#保密審查
#改編自2022 資訊學科能力競賽 台北市區複賽
n,m=map(int,input().split())
pas=input()
init=input()
while True:
  if pas in init:
    init=init.replace(pas, "", 1)
    # 使用 replace 將第一個找到的 pas 替換成空字串，次數設為 1
  else:
    break
print(init)
