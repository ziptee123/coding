# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/%E7%A8%8B%E5%BC%8F%E6%95%99%E5%AD%B8%E9%A1%8C/%E9%AB%98%E5%BA%A6%E8%A8%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#高度計
#改編自2020 資訊學科能力競賽 新北區複賽
n=int(input())
hrec=list(map(int,input().split()))
a,b=map(int,input().split())
s=0
for i in range(0,len(hrec),2):
  if a<=hrec[i]<=b:
    s+=hrec[i+1]
print(s)
