# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/%E7%A8%8B%E5%BC%8F%E6%95%99%E5%AD%B8%E9%A1%8C/%E5%B9%BE%E6%9C%88%E5%B9%BE%E6%97%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#幾月幾日
#改編自2020 資訊學科能力競賽 新北區複賽
month=[31,28,31,30,31,30,31,31,30,31,30,31] #不用字典，因為照著順序
k=int(input())
for i in range(1,13): # i 就是幾月
  if k<=month[i-1]:
    print(i,k)
    break
  else:
    k-=month[i-1]
