# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/APCS/%E5%AF%A6%E4%BD%9C%E7%AC%AC%E4%B8%80%E9%A1%8C/%E4%B8%83%E8%A8%80%E5%B0%8D%E8%81%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2021年9月實作題第1題：七言對聯
#g275
n=int(input())
for i in range(n):
  res=[]
  first=list(map(int,input().split()))
  second=list(map(int,input().split()))
  if (first[1]==first[3] or first[1]!=first[5])or(second[1]==second[3] or second[1]!=second[5]):
    res.append("A")
  if first[6]==0 or second[6]==1:
    res.append("B")
  if first[1]==second[1] or first[3]==second[3] or first[5]==second[5]:
    res.append("C")
  if not res:
    print("None")
  else:
    print("".join(res))
