# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/APCS/%E5%AF%A6%E4%BD%9C%E7%AC%AC%E4%B8%80%E9%A1%8C/%E6%95%B8%E5%AD%97%E9%81%8A%E6%88%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2022年6月實作題第1題：數字遊戲
#i399
abc=sorted(set(map(int,input().split())),reverse=True)
l=len(abc)
if l==3:
  print("1", *abc)
elif l==2:
  print("2", *abc)
else:
  print("3", *abc)
