# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/APCS/%E5%AF%A6%E4%BD%9C%E7%AC%AC%E4%B8%80%E9%A1%8C/%E6%9C%80%E5%B0%91%E7%9B%B8%E7%95%B0%E5%AD%97%E6%AF%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2018年 10月 實作題
#e313 最少相異字母
n=int(input())
s=[]
for _ in range(n):
  s.append(input())
print(min(s,key=lambda x:(len(set(x)), x)))
