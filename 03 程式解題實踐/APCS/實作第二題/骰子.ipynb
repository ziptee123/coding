# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/03%20%E7%A8%8B%E5%BC%8F%E8%A7%A3%E9%A1%8C%E5%AF%A6%E8%B8%90/APCS/%E5%AF%A6%E4%BD%9C%E7%AC%AC%E4%BA%8C%E9%A1%8C/%E9%AA%B0%E5%AD%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2020年7月實作題第2題：骰子
#f580
n,m=map(int,input().split())
dice=[[1,6,2,5,3,4] for p in range(n)]
def twis(dices):
  if b==-1:  #向前轉
    dic=dices[0]
    dices[0]=dices[4]
    dices[4]=dices[1]
    dices[1]=dices[5]
    dices[5]=dic
    return dices
  if b==-2:  #向右轉
    di=dices[0]
    dices[0]=dices[3]
    dices[3]=dices[1]
    dices[1]=dices[2]
    dices[2]=di
    return dices
for i in range(m):
  a,b=map(int,input().split())
  if b>0:
    dice[a-1],dice[b-1]=dice[b-1],dice[a-1]  #實際的編號不是從0開始，所以減1
  else:
    dice[a-1]=twis(dice[a-1])
print(*(dice[j][0] for j in range(n)))
