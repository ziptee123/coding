# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/02%20%E5%AD%B8%E7%BF%92%E8%AA%9E%E6%B3%95%E5%9F%BA%E7%A4%8E%E9%81%8B%E7%94%A8/%E8%AA%9E%E6%B3%95%E7%B7%B4%E7%BF%922%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
profile={"姓名":"小明",
    "年紀":18,
    "最愛食物":"洋芋片",}
print("選項:姓名、年紀、最愛食物")
choice=input("請輸入選項:")
if choice in profile:
  answer=profile[choice]
  print(f"我的{choice}是{profile[choice]}!")
else:
  print("沒有這個選項喔!")

# %%
def cal(price):
  print(f"加上運費後，一共是{price+60}元!")
cal(500)
cal(100)

# %%
def dis(price):
  total=(price)*0.8
  return total
bill=dis(1000)
print(f"打折後的價格是{bill}元")

# %%
import random
secret = random.randint(1, 100)
history = []

while True:
    try:
        guess = int(input("請猜一個數字:"))
        history.append(guess)
        if guess > secret:
            print("太大了!")
        elif guess < secret:
            print("太小了!")
        else:
            print("正確!")
            break
    except ValueError:
        print("請輸入數字!")
print(f"你總共猜了這些數字:{history}")
print(f"你總共猜了{len(history)}次!")

# %%
import random
import time
def upg(level):
  cho=random.randint(1,100)
  if cho<=70:
    print("強化成功!等級加1。")
    level=level+1
  else:
    print("強化失敗。")
    if level>1:
      print("等級減1。")
      level=level-1
    else:
      print("等級不變。")
  return level
level=1
while True:
  try:
    tis=int(input("請問你要強化幾次?(輸入0離開)"))
    if tis==0:
      print("不升級，已離開。")
      break
    for i in range(tis):
      print(f"第{i+1}次升級中...")
      time.sleep(0.5)
      level=upg(level)
    print(f"你現在的等級是{level}")
  except ValueError:
    print("請輸入數字!")

# %%
import random
import time

def dice():
    dice = random.randint(1, 6)
    return dice

pocket = 100
while True:
    try:
        money = int(input("請輸入你要下注的金額:(輸入0離開)"))
        if money == 0:
            print("你不下注。選擇離開。")
            break

        player = dice()
        opponent = dice()
        print("擲骰子中...")
        time.sleep(1)
        print(f"你擲的骰子是{player},對方擲的骰子是{opponent}")

        if player > opponent:
            print("你贏了！")
            pocket = pocket + money
        elif player < opponent:
            print("你輸了！")
            pocket = pocket - money
        else:
            print("平手！")

        print(f"你現在有{pocket}元")

    except ValueError:
        print("請輸入數字！")

# %%
import random
def add():
  number1=random.randint(1,50)
  number2=random.randint(1,50)
  addi=number1+number2
  print(f"請計算這道題目:{number1}+{number2}")
  return addi
addi = add()
while True:
  try:
    ans=int(input("請輸入答案。"))
    if ans!=addi:
      print("回答錯誤!請重新作答。")
    else:
      print("回答正確，登入成功。")
      break
  except ValueError:
    print("請輸入數字!")

# %%
import random
import time
ans = random.randint(1,10)
print("炸彈已啟動！5秒內輸入正確密碼解除。")
start = time.time()
while True:
  if time.time()-start > 5:
      print("時間到！炸彈爆炸！")
      break
  try:
    ito = int(input("請輸入密碼:"))
    if ito == ans:
      print("回答正確! 炸彈已解除。")
      break
    else:
      print("密碼錯誤!")
  except ValueError:
      print("輸入無效! 炸彈爆炸!")
      break

# %%
n=int(input())
result=[]
for i in range(1,n+1):
  if i%3==0:
    result.append(i)
print(sum(result))

# %%
n=int(input())
result=sum(i for i in range(1,n+1)if i%3==0)
print(result)

# %%
n=int(input())
result=0
for i in range(1,n+1):
  if i%3!=0:
    continue
  result+=i
print(result)
