# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/02%20%E5%AD%B8%E7%BF%92%E8%AA%9E%E6%B3%95%E5%9F%BA%E7%A4%8E%E9%81%8B%E7%94%A8/00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input())
if a==0:
  print("0")
elif a==1:
  print("1")
else:
  print("none")
