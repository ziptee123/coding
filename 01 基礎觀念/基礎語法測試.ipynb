# %% [markdown]
# <a href="https://colab.research.google.com/github/ziptee123/coding/blob/main/01%20%E5%9F%BA%E7%A4%8E%E8%A7%80%E5%BF%B5/%E5%9F%BA%E7%A4%8E%E8%AA%9E%E6%B3%95%E6%B8%AC%E8%A9%A6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello,這是我的第一行程式!")

# %%
name="小明"
age=20
print(name)
print(age)

# %%
name="小明"
food="鹽酥雞"
print(f"我是{name}，我最喜歡吃{food}！")

# %%
food=input("你今天想吃什麼食物?")
print(f"真巧，我也想吃{food}")

# %%
drink=int(input("請問這杯飲料多少錢?"))
print(f"買三杯需要{drink*3}元")

# %%
for i in range(1,6):
  print(f"這是我印出的第{i}遍!")

# %%
def cal(price):
  print(f"加上運費後，一共是{price+60}元!")
cal(500)
cal(100)

# %%
def dis(price):
  total=(price)*0.8
  return total
bill=dis(1000)
print(f"打折後的價格是{bill}元")

# %%
n=int(input())
result=[]
for i in range(1,n+1):
  if i%3==0:
    result.append(i)
print(sum(result))

# %%
n=int(input())
result=sum(i for i in range(1,n+1)if i%3==0)
print(result)

# %%
n=int(input())
result=0
for i in range(1,n+1):
  if i%3!=0:
    continue
  result+=i
print(result)
